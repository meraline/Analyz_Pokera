# %% [markdown]
# ## Цель иследования
#  - выявить частоту (периоды) повторяемости наблюдаемой характеристики 'rang_namber'
#  - создать модель для ML позволяющую предиктить периоды на новых данных
#  - предположить факторы влияющие на чатсоту повторяемости
#  - https://github.com/julianandrews/flopferret/blob/master/flopferret/board_texture.py

# %%
import re
import pandas as pd
from datetime import datetime
import eval7, pprint
from poker.room.pokerstars import PokerStarsHandHistory
from poker.hand import Hand, Combo
import numpy as np
from phevaluator import evaluate_cards
import matplotlib.pyplot as plt
plt.style.use('dark_background') #стиль графиков

# %%
# Создали словарь
data_pd = {'TypeOfRoom': [], 'HandId': [], 'Tournament': [], 'Level': [], 'Date': [], 'Hour': [],
           'TimeZoneAbb': [], 'Table': [], 'NoOfPlayers': [], 'bain': [], 'HandHiro': [], 'Board': []}

# Открываем файл
with open('dim1000.txt', 'r') as f: #Poker_\SNG dimetruk 1-54133.txt
    data = f.read()
    
# Ищем нужные данные
result = re.findall('(\w+) Hand #(\d*): Tournament #(\d*),(.*) Level (.*) - (\d{4}/\d+/\d+) (\d+\D\d+\D\d+) (\w*)', data)
Tables = re.findall('Table \'.*\' (.*) Seat .*\n', data)
bains = re.findall('(\D\d+\.\d+\+\D\d+\.\d+)', data)
HandHiros = re.findall("Dealt to dimetruk \D(.. ..)\D", data)
Boards = re.findall("Board \[(.*)\]", data)


# Считаем сколко фишек
s = re.findall('Seat (\d).*chips', data)
s = [int(x) for x in s]
seats = []
length = 1
for i in range(len(s)-1):
    if s[i+1] < s[i]:
        seats.append(length)
        length = 1
    else:
        length += 1
seats.append(length)


# ЗАполнЯем словарь данными
for r, table, bain, seat, handHiro, board in zip(result, Tables, bains, seats, HandHiros, Boards):
    data_pd['TypeOfRoom'].append(r[0])
    data_pd['HandId'].append(r[1])
    data_pd['Tournament'].append(r[2])
    # data_pd['info'].append(r[3])
    data_pd['Level'].append(r[4])
    data_pd['Date'].append(r[5])
    data_pd['Hour'].append(r[6])
    data_pd['TimeZoneAbb'].append(r[7])
    data_pd['Table'].append(table) #table
    data_pd['NoOfPlayers'].append(seat)
    data_pd['bain'].append(bain)
    data_pd['HandHiro'].append(handHiro)
    data_pd['Board'].append(board)

# Создаём ДатаФрейм
dataf = pd.DataFrame(data_pd)
dataf.head()
# Out:
#    TypeOfRoom        HandId  Tournament       Level        Date      Hour  \
# 0  PokerStars  226484810600  3187437334  IV (40/80)  2021/05/05  19:56:10
# 1  PokerStars  226484828418  3187437334  V (60/120)  2021/05/05  19:56:57
# 2  PokerStars  226484843891  3187437334  V (60/120)  2021/05/05  19:57:39
# 3  PokerStars  226484859594  3187437334  V (60/120)  2021/05/05  19:58:21
# 4  PokerStars  226484865470  3187437334  V (60/120)  2021/05/05  19:58:37
#
#   TimeZoneAbb  Table  NoOfPlayers          bain HandHiro           Board
# 0         MSK  6-max            2  $13.79+$1.21    Jh Td  8h 8c 7c 3h 6d
# 1         MSK  6-max            2  $13.79+$1.21    Ts 3s  2s 6s As Jc Th
# 2         MSK  6-max            2  $13.79+$1.21    4s 5c  Ks Qh 7h Tc 4c
# 3         MSK  6-max            2  $13.79+$1.21    9c Th        7s 4d Qd
# 4         MSK  6-max            2  $13.79+$1.21    7h 9d  2h Qd 5d Ts 3s

# %% [markdown]
# ## Преобразуем строковые данные

# %%
date = data_pd['Date']
time = data_pd['Hour']

dataf["Date"] = pd.to_datetime(data_pd['Date'])
dataf["Time"] = pd.to_timedelta(data_pd['Hour'])

dataf["DateTime"] = dataf["Date"] + dataf["Time"]
dataf["DateTime"]

# filter by single day
dataf_m = dataf[dataf['DateTime'].dt.strftime('%d') == '06']

dataf.Tournament = dataf.Tournament.astype('int64')
dataf = dataf.astype({'HandId': np.int64, 'Tournament': np.int64})

# %%
dataf_m
# Out:
#      TypeOfRoom        HandId  Tournament           Level       Date  \
# 28   PokerStars  226513978208  3187736508       I (10/20) 2021-05-06
# 29   PokerStars  226514229033  3187736508      II (15/30) 2021-05-06
# 30   PokerStars  226514380835  3187736508     III (25/50) 2021-05-06
# 31   PokerStars  226514480233  3187736508     III (25/50) 2021-05-06
# 32   PokerStars  226514505604  3187736508     III (25/50) 2021-05-06
# ..          ...           ...         ...             ...        ...
# 206  PokerStars  226521443361  3188224941   VII (100/200) 2021-05-06
# 207  PokerStars  226521625242  3188224941   VII (100/200) 2021-05-06
# 208  PokerStars  226521783524  3188224941   VII (100/200) 2021-05-06
# 209  PokerStars  226521853554  3188224941  VIII (150/300) 2021-05-06
# 210  PokerStars  226521875804  3188224941  VIII (150/300) 2021-05-06
#
#          Hour TimeZoneAbb  Table  NoOfPlayers          bain HandHiro  \
# 28   20:13:37         MSK  9-max            8  $13.70+$1.30    Jc 6d
# 29   20:22:02         MSK  9-max            8  $13.70+$1.30    Qd Ah
# 30   20:27:07         MSK  9-max            7  $13.70+$1.30    Kd Jc
# 31   20:30:22         MSK  9-max            7  $13.70+$1.30    Ah As
# 32   20:31:11         MSK  9-max            7  $13.70+$1.30    Qd 7c
# ..        ...         ...    ...          ...           ...      ...
# 206  23:45:24         MSK  9-max            7  $13.70+$1.30    Kc Ac
# 207  23:49:55         MSK  9-max            6  $13.70+$1.30    Tc Js
# 208  23:53:55         MSK  9-max            5  $13.70+$1.30    Ad 4d
# 209  23:56:21         MSK  9-max            5  $13.70+$1.30    5c 5s
# 210  23:57:14         MSK  9-max            5  $13.70+$1.30    Qc 9d
#
#               Board            Time            DateTime
# 28      Js Ks 4d Ah 0 days 20:13:37 2021-05-06 20:13:37
# 29   Ts Kh Jc 8c 7d 0 days 20:22:02 2021-05-06 20:22:02
# 30         8s 6d 5d 0 days 20:27:07 2021-05-06 20:27:07
# 31         Th Jc 2d 0 days 20:30:22 2021-05-06 20:30:22
# 32   Kd Ad 8h Th 8c 0 days 20:31:11 2021-05-06 20:31:11
# ..              ...             ...                 ...
# 206  9s 8d Kd Qd 3s 0 days 23:45:24 2021-05-06 23:45:24
# 207  2d 2h 7d 5s Ts 0 days 23:49:55 2021-05-06 23:49:55
# 208  8d Td Jc 3s 6h 0 days 23:53:55 2021-05-06 23:53:55
# 209  5h Kc 7c Ad Jh 0 days 23:56:21 2021-05-06 23:56:21
# 210  As 2c 9s Ad 4d 0 days 23:57:14 2021-05-06 23:57:14
#
# [183 rows x 14 columns]

# %%
nov_mar_series = pd.Series(pd.date_range("2013-11-15", "2014-03-15"))
#create timestamp without year
nov_mar_no_year = nov_mar_series.map(lambda x: x.strftime("%m-%d"))
nov_mar_no_year
# Out:
# 0      11-15
# 1      11-16
# 2      11-17
# 3      11-18
# 4      11-19
#        ...
# 116    03-11
# 117    03-12
# 118    03-13
# 119    03-14
# 120    03-15
# Length: 121, dtype: object

# %%
# #add a yearless timestamp to the dataframe
# df["no_year"] = df['nov_mar_series'].map(lambda x: x.strftime("%m-%d"))
# no_year_mask = df['no_year'].isin(nov_mar_no_year)
# df[no_year_mask]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11024/4158025095.py in <module>
#       1 #add a yearless timestamp to the dataframe
# ----> 2 df["no_year"] = df[(pd.date_range("2013-11-15", "2014-03-15"))].map(lambda x: x.strftime("%m-%d"))
#       3 no_year_mask = df['no_year'].isin(nov_mar_no_year)
#       4 df[no_year_mask]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [DatetimeIndex(['2013-11-15', '2013-11-16', '2013-11-17', '2013-11-18',\n               '2013-11-19', '2013-11-20', '2013-11-21', '2013-11-22',\n               '2013-11-23', '2013-11-24',\n               ...\n               '2014-03-06', '2014-03-07', '2014-03-08', '2014-03-09',\n               '2014-03-10', '2014-03-11', '2014-03-12', '2014-03-13',\n               '2014-03-14', '2014-03-15'],\n              dtype='datetime64[ns]', length=121, freq='D')] are in the [columns]"

# %% [markdown]
# ## Фильтруем турниры по числу рук выше среднего (> mean)

# %%
data_filter = dataf[['Tournament', 'HandId','DateTime', 'Time', 'HandHiro', 'Board']]
data_filter.head()
# Out:
#    Tournament        HandId            DateTime            Time HandHiro  \
# 0  3187437334  226484810600 2021-05-05 19:56:10 0 days 19:56:10    Jh Td
# 1  3187437334  226484828418 2021-05-05 19:56:57 0 days 19:56:57    Ts 3s
# 2  3187437334  226484843891 2021-05-05 19:57:39 0 days 19:57:39    4s 5c
# 3  3187437334  226484859594 2021-05-05 19:58:21 0 days 19:58:21    9c Th
# 4  3187437334  226484865470 2021-05-05 19:58:37 0 days 19:58:37    7h 9d
#
#             Board
# 0  8h 8c 7c 3h 6d
# 1  2s 6s As Jc Th
# 2  Ks Qh 7h Tc 4c
# 3        7s 4d Qd
# 4  2h Qd 5d Ts 3s

# %%
# data_filter.groupby(['Tournament']).agg({'HandId': "count"}).reset_index()
# Out:
#     Tournament  HandId
# 0   3187437334      25
# 1   3187445431       3
# 2   3187736508      18
# 3   3187738267      13
# 4   3187770419       8
# 5   3188052591      16
# 6   3188065522      10
# 7   3188077995      48
# 8   3188080898       4
# 9   3188088059      45
# 10  3188224941      76
# 11  3188715462       9
# 12  3188920119      30
# 13  3189227656      44
# 14  3189369567      26
# 15  3189414322      10
# 16  3189420361      20
# 17  3189917591       7
# 18  3189938750      32
# 19  3189943627      21
# 20  3189961915      17
# 21  3190268420      16
# 22  3190275458      15
# 23  3190323036       6
# 24  3190325009      54
# 25  3192016076       7
# 26  3192070875      20
# 27  3192074823       4
# 28  3192613092       2
# 29  3199808034      12
# 30  3200883791      13
# 31  3200903456      10
# 32  3202694837      19
# 33  3203173572       8
# 34  3203198779      18
# 35  3203221938      18
# 36  3203262490      26
# 37  3203287977      10
# 38  3203890226      11
# 39  3204122579       5
# 40  3204283203      15
# 41  3206184643       9
# 42  3227151913      27
# 43  3227159788      65
# 44  3227430197      32
# 45  3228689682      13
# 46  3228838622      12
# 47  3228886942       5
# 48  3229239210       5
# 49  3231914115      40
# 50  3242835350       9
# 51  3242858326      12

# %%
#  Фильтруйте value_counts с помощью isin  https://softhints.com/pandas-how-to-filter-results-of-value_counts/
# data_filter[data_filter['Tournament'].isin(data_filter['Tournament'].value_counts()[data_filter['Tournament'].value_counts()>30].index)].Tournament

# %%
#  Используйте group by и lambda для имитации фильтра для value_counts()
df = data_filter.groupby('Tournament').filter(lambda x: len(x) > (data_filter['Tournament'].value_counts().mean()))
df
# Out:
#      Tournament        HandId            DateTime            Time HandHiro  \
# 0    3187437334  226484810600 2021-05-05 19:56:10 0 days 19:56:10    Jh Td
# 1    3187437334  226484828418 2021-05-05 19:56:57 0 days 19:56:57    Ts 3s
# 2    3187437334  226484843891 2021-05-05 19:57:39 0 days 19:57:39    4s 5c
# 3    3187437334  226484859594 2021-05-05 19:58:21 0 days 19:58:21    9c Th
# 4    3187437334  226484865470 2021-05-05 19:58:37 0 days 19:58:37    7h 9d
# ..          ...           ...                 ...             ...      ...
# 974  3231914115  228379928522 2021-07-18 15:41:04 0 days 15:41:04    9d Ad
# 975  3231914115  228379944646 2021-07-18 15:41:32 0 days 15:41:32    5h 4c
# 976  3231914115  228379961865 2021-07-18 15:42:31 0 days 15:42:31    4c Tc
# 977  3231914115  228379965572 2021-07-18 15:42:44 0 days 15:42:44    As Jc
# 978  3231914115  228379998769 2021-07-18 15:44:38 0 days 15:44:38    3d Kh
#
#               Board
# 0    8h 8c 7c 3h 6d
# 1    2s 6s As Jc Th
# 2    Ks Qh 7h Tc 4c
# 3          7s 4d Qd
# 4    2h Qd 5d Ts 3s
# ..              ...
# 974  2h 3d Kc 8h 8s
# 975     Jc 9d 6c 9s
# 976        Ac 9s 6h
# 977  Td 8s Ks Ac 4d
# 978  Js 9s Th 9d 8h
#
# [631 rows x 6 columns]

# %%
df.Tournament.value_counts()
# Out:
# 3188224941    76
# 3227159788    65
# 3190325009    54
# 3188077995    48
# 3188088059    45
# 3189227656    44
# 3231914115    40
# 3227430197    32
# 3189938750    32
# 3188920119    30
# 3227151913    27
# 3203262490    26
# 3189369567    26
# 3187437334    25
# 3189943627    21
# 3189420361    20
# 3192070875    20
# Name: Tournament, dtype: int64

# %%
# Prepare Data
df_plot = df.groupby('Tournament').size()

# Make the plot with pandas
df_plot.plot(kind='pie', subplots=True, figsize=(8, 8))
plt.title("Колличество турниров")
plt.ylabel("")
plt.show()

# %%
# объеденяем руку и борд, выводим название комбинации

# df['hand'] = df['HandHiro'] + " " + df['Board']
# # hand = df['hand'].values[7].split()
# # print(hand)

# hand_ev = [eval7.Card(s) for s in (df['hand'].values[7].split())]
# rang = eval7.evaluate(hand_ev)   # ранг комбинации
# # print(rang)

# eval7s = eval7.handtype(rang)  #  название комбинации

# df['rang'] = eval7.evaluate(hand_ev)
# df['eval7s'] =  eval7.handtype(rang)

# %%
# def new_type(row):
#     if row.traffic_source.lower() in ('yandex', 'google'):
#         return 'organic'
#     elif row.traffic_source.lower() in ('paid', 'email'):
#         if row.region.lower() == 'russia':
#             return 'ad'
#         else:
#             return 'other'

# %%
# log['source_type'] = log.apply(new_type, axis = 1)
# log.head(12)

# %%
# log.loc[log.traffic_source.isin(['yandex', 'google']), 'traffic_type'] = 'organic'

# %%
df['hand_rang'] = df['HandHiro'] + " " + df['Board']
df['hand_rang']

print(type(df['hand_rang']), type(df['hand_rang'].values[7].split()))
df['hand_rang'].values[0].split()
# Out:
# <class 'pandas.core.series.Series'> <class 'list'>
# ['Jh', 'Td', '8h', '8c', '7c', '3h', '6d']

# %%
# df['hand_rang'].to_list()
# df['hand_rang'].tolist()
# np.array(df['hand_rang'].tolist())
# Ls = list(df['hand_rang'])
ls = df['hand_rang'].str.split()
ls
# Out:
# 0      [Jh, Td, 8h, 8c, 7c, 3h, 6d]
# 1      [Ts, 3s, 2s, 6s, As, Jc, Th]
# 2      [4s, 5c, Ks, Qh, 7h, Tc, 4c]
# 3              [9c, Th, 7s, 4d, Qd]
# 4      [7h, 9d, 2h, Qd, 5d, Ts, 3s]
#                    ...
# 974    [9d, Ad, 2h, 3d, Kc, 8h, 8s]
# 975        [5h, 4c, Jc, 9d, 6c, 9s]
# 976            [4c, Tc, Ac, 9s, 6h]
# 977    [As, Jc, Td, 8s, Ks, Ac, 4d]
# 978    [3d, Kh, Js, 9s, Th, 9d, 8h]
# Name: hand_rang, Length: 631, dtype: object

# %%
# напишем функцию получения ранг комбинации

def evaluate_(hand):
    """
    На вход получает карты, на выход 
    число ранг по eval7
    """
    hand_ev = [eval7.Card(s) for s in (hand)]
    return eval7.evaluate(hand_ev)

a = ('Jh', 'Td', '8h', '8c', '7c', '3h', '6d')
evaluate_(a)
# Out:
# 17209424

# %%
# напишем функцию получения названия ранга

def handtype_(rang):
    """
    На вход получает ранг, на выход 
    название комбинации
    """
    return eval7.handtype(rang)

handtype_(17209424)
# Out:
# 'Pair'

# %%
# Применим функцию к столбцу hand  и запишем в новый столбец rang_namber

df['rang_namber'] = df['hand_rang'].str.split().apply(evaluate_)
df['handtypes'] = df['rang_namber'].apply(handtype_)
df[['rang_namber', 'handtypes','HandHiro', 'Board']].head(20)
# df['filter'] = df.loc[df.handtypes.str.contains('Two Pair', 'Trips', 'Straight', 'Full House', 'Quads', 'Straight Flush'), 'rang_namber']
# Out:
#     rang_namber  handtypes HandHiro           Board
# 0      17209424       Pair    Jh Td  8h 8c 7c 3h 6d
# 1      84706320      Flush    Ts 3s  2s 6s As Jc Th
# 2      16956032       Pair    4s 5c  Ks Qh 7h Tc 4c
# 3        690002  High Card    9c Th        7s 4d Qd
# 4        690003  High Card    7h 9d  2h Qd 5d Ts 3s
# 5        832833  High Card    7d 3d        Kh 6c Ac
# 6      17278256       Pair    5c 9h  Qs 2d 9c 4c 7s
# 7      17392128       Pair    Jd 8s        4h 2c Jc
# 8      50968576      Trips    8d Jh  Kc 7h Js Td Jc
# 9      17401680       Pair    5s 9d  7s Jd Td Js 4c
# 10       825393  High Card    5h Ad        3c Ts Js
# 11     17418352       Pair    Jc Th     Ah Js 9c 8h
# 12       694373  High Card    7s Qc     5s Js 8d Td
# 13     34351872   Two Pair    Ac 3h  As Ks 4s 4d 9s
# 14     33692160   Two Pair    4s Ts  4c Qc 3h 3c 9s
# 15     17087104       Pair    Tc 4c  6d 5c 6s Qs Ks
# 16     84715347      Flush    Kh 7c  9d 5d Ad Qd 7d
# 17     17344864       Pair    7c Jh  Td 3c Qd Th 8c
# 18     17353632       Pair    9d Qc  7h Tc Ac Kc Ts
# 19     17217616       Pair    8d 7s  4s 8s 5h Td Ks

# %%
# df.sort_values(by=['handtypes', 'rang_namber'])

# %%
# df.groupby('handtypes')['rang_namber'].value_counts()

# %% [markdown]
# ### Создадим сводную таблицу, что-бы проверить наличие аномалий

# %%
# filter by single day
dataf_m = dataf[dataf['DateTime'].dt.strftime('%d') == '06']

# %%
df[['Tournament', 'handtypes', 'rang_namber']].head()  # применим фильтер по столбцам
# Out:
#    Tournament  handtypes  rang_namber
# 0  3187437334       Pair     17209424
# 1  3187437334      Flush     84706320
# 2  3187437334       Pair     16956032
# 3  3187437334  High Card       690002
# 4  3187437334  High Card       690003

# %%
pd.pivot_table(df, index=["Tournament", "handtypes"])
# Out:
#                              HandId   rang_namber
# Tournament handtypes
# 3187437334 Flush       2.264849e+11  8.471083e+07
#            High Card   2.264849e+11  7.465208e+05
#            Pair        2.264850e+11  1.727048e+07
#            Trips       2.264849e+11  5.096858e+07
#            Two Pair    2.264851e+11  3.407731e+07
# ...                             ...           ...
# 3231914115 Full House  2.283795e+11  1.014866e+08
#            High Card   2.283796e+11  7.700521e+05
#            Pair        2.283797e+11  1.727938e+07
#            Trips       2.283794e+11  5.048320e+07
#            Two Pair    2.283795e+11  3.426540e+07
#
# [93 rows x 2 columns]

# %%
# явно определив столбцы, которые нам нужны,
pd.pivot_table(df,
               index=["Tournament", "handtypes"],
               values=["rang_namber"],
               aggfunc= len)   # aggfunc=[np.mean, len])
# Out:
#                        rang_namber
# Tournament handtypes
# 3187437334 Flush                 2
#            High Card             5
#            Pair                 13
#            Trips                 1
#            Two Pair              4
# ...                            ...
# 3231914115 Full House            1
#            High Card            13
#            Pair                 19
#            Trips                 1
#            Two Pair              5
#
# [93 rows x 1 columns]

# %%
df.Tournament.value_counts()
# Out:
# 3188224941    76
# 3227159788    65
# 3190325009    54
# 3188077995    48
# 3188088059    45
# 3189227656    44
# 3231914115    40
# 3227430197    32
# 3189938750    32
# 3188920119    30
# 3227151913    27
# 3203262490    26
# 3189369567    26
# 3187437334    25
# 3189943627    21
# 3189420361    20
# 3192070875    20
# Name: Tournament, dtype: int64

# %%
# df['Time'].value_counts()

# %%
# Prepare Data
df_plot = df.groupby('handtypes').size()

# Make the plot with pandas
df_plot.plot(kind='area', subplots=True, figsize=(8, 8))
plt.title("Колличество комбинаций")
plt.ylabel("")
plt.show()

# %%
# df['DateTime'] = df['DateTime'][(df['DateTime'] > '2018-10-01 20:00:00') & (df['DateTime'] < '2022-10-02 00:00:00')]
# df['DateTime']

# %%
# отфильтруем комбинации "старшая карта" и "пара"
df['no_par'] = df['rang_namber'][df['rang_namber'] > 50000000] #[((df['rang_namber'] > 50000000) & (df['rang_namber'] < 60000000))]
df = df.dropna()
df[['Time', 'no_par', 'handtypes']].head(10)
# df['filter_Two Pair'] = df['handtypes'][df['handtypes'] == 'Two Pair']
# df['filter_Two Pair']
# Out:
#                Time       no_par   handtypes
# 99  0 days 19:12:53   50776576.0       Trips
# 101 0 days 19:17:44   84702769.0       Flush
# 126 0 days 19:37:12   67436544.0    Straight
# 157 0 days 19:25:27  101105664.0  Full House
# 158 0 days 19:28:36   67371008.0    Straight
# 164 0 days 19:41:41   84579632.0       Flush
# 188 0 days 20:06:07   84650065.0       Flush
# 199 0 days 23:30:09  101466112.0  Full House
# 201 0 days 23:35:07   51082752.0       Trips
# 209 0 days 23:56:21   50580224.0       Trips

# %%
df.isnull().sum()
# Out:
# Tournament     0
# HandId         0
# DateTime       0
# Time           0
# HandHiro       0
# Board          0
# hand_rang      0
# rang_namber    0
# handtypes      0
# no_par         0
# dtype: int64

# %%
# преобразуем время во временной ряд

# %%
idx = df['Time']
 # datetime.timedelta(seconds=24*60*60).total_seconds()

# second = df['DateTime'].dt.total_seconds()
# second

# idx = pd.date_range(df['DateTime'], periods=5, freq="H")
# idx
tim = pd.Series(range(len(idx)), index=idx)

# ts.resample("2H").mean()
tim
# Out:
# Time
# 0 days 19:12:53     0
# 0 days 19:17:44     1
# 0 days 19:37:12     2
# 0 days 19:25:27     3
# 0 days 19:28:36     4
# 0 days 19:41:41     5
# 0 days 20:06:07     6
# 0 days 23:30:09     7
# 0 days 23:35:07     8
# 0 days 23:56:21     9
# 0 days 00:02:37    10
# 0 days 00:05:58    11
# 0 days 00:06:32    12
# 0 days 00:18:34    13
# 0 days 00:20:13    14
# 0 days 00:21:04    15
# 0 days 00:21:51    16
# 0 days 00:23:35    17
# 0 days 17:45:16    18
# 0 days 18:01:00    19
# 0 days 18:07:20    20
# 0 days 23:18:20    21
# 0 days 23:33:08    22
# 0 days 23:38:42    23
# 0 days 22:46:53    24
# 0 days 22:48:48    25
# 0 days 22:57:37    26
# 0 days 22:58:16    27
# 0 days 22:58:31    28
# 0 days 15:07:14    29
# 0 days 15:12:21    30
# 0 days 15:17:11    31
# dtype: int64

# %%
# df = df.set_index("Time")
# df

# %%
import matplotlib.pyplot as plt
 
# Using a inbuilt style to change
# the look and feel of the plot
plt.style.use("classic")
 
# setting figure size to 12, 10
plt.figure(figsize=(12, 10))
 
# Labelling the axes and setting
# a title
plt.xlabel("Time")
plt.ylabel("Values")
plt.title("Sample Time Series Plot")
 
# plotting the "A" column alone
plt.plot(df["handtypes"])

# %%
df.plot(subplots=True, figsize=(12, 15))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
# # # idx = pd.date_range('2019-01-01', periods=48, freq='H')
# # x = pd.Series(range(len(idx)), index=idx)
# y = tim
# # add 'hour' and 'day' columns in the dataframe
# d = {'x': x, 'y': y, 'hour': idx.hour, 'day': idx.day}
# df = pd.DataFrame(data=d)
# # use 'hour' as x axis to plot, and 'day' as marker color
# df.plot.scatter(x='hour', y='y', c='day', colormap='rainbow')
# plt.show()

# %%
data.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11024/3048952558.py in <module>
# ----> 1 data.dtypes
#
# AttributeError: 'str' object has no attribute 'dtypes'

# %%
# установитьdatetimeОбъект в качестве индекса кадра данных
data = data.set_index('DateTime')
data.head()

# %%
# data.plot(grid=True)

data['filter'].plot(kind='bar')

# import matplotlib.pyplot as plt
# from matplotlib.dates import DateFormatter
# # Группировка за месяц
# df_month = data.resample("M").mean()

# fig, ax = plt.subplots(figsize=(10, 6))
# ax.xaxis.set_major_formatter(DateFormatter('%Y-%m'))
# ax.bar(
#     df_month['2018':].index, 
#     df_month.loc['2016':, "filter"], 
#     width=25, align='center')

# %%
data.plot(kind='scatter', 
        x='DateTime', 
        y='filter', 
        title='Связь между жёсткостью воды и средней годовой смертностью')
