# %%
# !pip install jmespath

# %%
import jmespath
import json
from pprint import pprint

# %%
with open('skelet.json', 'r', encoding='utf8') as f:
    text = json.load(f)
    pprint(text)
# Out:
# {'animations': {'Landscape/appear': {'bones': {'Card_0': {'rotate': [{'angle': -29.32,
#                                                                       'curve': 'stepped'},
#                                                                      {'angle': -29.32,
#                                                                       'c3': 0.517,
#                                                                       'curve': 0.485,
#                                                                       'time': 0.3333},
#                                                                      {'curve': 'stepped',
#                                                                       'time': 0.6},
#                                                                      {'time': 3.6333},
#                                                                      {'angle': 2.96,
#                                                                       'time': 3.8},
# ...
